# %% [markdown]
# <a href="https://colab.research.google.com/github/ElCaballo69/JDPR-Methods-Lecture-3/blob/main/Lecture_11_numerical_integration_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numerical Integration Methods
#
# This notebook provides an overview of common numerical integration methods, including Trapezoidal Rule, Simpson's Rule, and Gaussian Quadrature. Each method includes a step-by-step algorithm and example Python code.

# %% [markdown]
# ## Trapezoidal Rule
#
# ### Algorithm:
# 1. Divide the interval [a, b] into n subintervals of equal width h = (b - a)/n.
# 2. Compute the sum: Integral ≈ (h/2) * [f(x₀) + 2f(x₁) + 2f(x₂) + ... + 2f(xₙ₋₁) + f(xₙ)].
# 3. Return the result.

# %%
def trapezoidal(f, a, b, n):
    h = (b - a) / n
    s = 0.5 * (f(a) + f(b))
    for i in range(1, n):
        s += f(a + i * h)
    return h * s

import math
f = lambda x: math.sin(x)
print(trapezoidal(f, 0, math.pi, 100))
# Out:
# 1.9998355038874436

# %% [markdown]
# ## Simpson's Rule
#
# ### Algorithm:
# 1. Divide the interval [a, b] into an even number n of subintervals.
# 2. Compute the sum: Integral ≈ (h/3) * [f(x₀) + 4f(x₁) + 2f(x₂) + 4f(x₃) + ... + 4f(xₙ₋₁) + f(xₙ)].
# 3. Return the result.

# %%
def simpson(f, a, b, n):
    h = (b - a) / n
    s = f(a) + f(b)
    for i in range(1, n):
        if i % 2 == 0:
            s += 2 * f(a + i * h)
        else:
            s += 4 * f(a + i * h)
    return (h / 3) * s

import math
f = lambda x: math.sin(x)
print(simpson(f, 0, math.pi, 100))
# Out:
# 2.0000000108245044
